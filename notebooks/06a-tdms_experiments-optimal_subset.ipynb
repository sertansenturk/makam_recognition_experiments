# %%
from pathlib import Path
from typing import Dict

import mre

import mlflow
import numpy as np
import pandas as pd
import seaborn as sns

from matplotlib import pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## helper functions
#
# We only need these once in the experiments, therefore there is no need to add them to `mre`.

# %%
def bhat(mtx1, mtx2):
    return -np.log(np.sum(np.sqrt(mtx1 * mtx2)))

# # code ported from https://github.com/sankalpg/Library_PythonNew
# EPS = np.finfo(np.float).resolution
# def sym_kld(mtx1, mtx2):
#     mtx1 = mtx1 + EPS
#     mtx2 = mtx2 + EPS
#     return mtx1 * np.log(mtx1/mtx2) + mtx2 * np.log(mtx2/mtx1)

# %%
def prepare_dataset(
    annotations,
    tdms_files,
    compression_exponent: float = None,  # no compression
    kernel_width: float = None # no smoothing
):
    NUM_BINS = int(1200 / mre.data.TimeDelayedMelodySurface.STEP_SIZE)
    
    num_samples = len(annotations.data)
    num_features = NUM_BINS * NUM_BINS

    # prepare features
    X = np.zeros((num_samples, num_features))
    mbids = np.array([])
    for ii, tf in enumerate(tdms_files):
        tdms = mre.data.TDMSFeature.from_json(tf)
        if compression_exponent is not None:
            tdms.compression_exponent = compression_exponent
            tdms.compress()
        if kernel_width is not None:
            tdms.kernel_width = kernel_width
            tdms.smoothen()
        vals = tdms.embedding

        if vals.size != num_features:
            raise ValueError(
                "%s has %d bins instead of %d."
                % (tf, vals.size, num_features)
            )
        X[ii, :] = vals.reshape(-1)
        mbids = np.append(mbids, Path(tf).stem)

    y = annotations.data.set_index("mbid").loc[mbids].makam.values

    return mre.data.dataset.Dataset(X, y)

# %% [markdown]
# # Read data

# %% [markdown]
# ## Annotations

# %%
annotations = mre.data.Annotation.from_mlflow()
display(annotations.head())
# Out:
#                               dunya_uid       makam  \
# 0  00f1c6d9-c8ee-45e3-a06f-0882ebcb4e2f  Acemasiran
# 1  168f7c75-84fb-4316-99d7-acabadd3b2e6  Acemasiran
# 2  24f549dd-3fa4-4e9b-a356-778fbbfd5cad  Acemasiran
# 3  407bb0b4-f19b-42ab-8c0a-9f1263126951  Acemasiran
# 4  443819eb-6092-420c-bd86-d946a0ad6555  Acemasiran
#
#                                               mb_url  \
# 0  http://musicbrainz.org/recording/00f1c6d9-c8ee...
# 1  http://musicbrainz.org/recording/168f7c75-84fb...
# 2  http://musicbrainz.org/recording/24f549dd-3fa4...
# 3  http://musicbrainz.org/recording/407bb0b4-f19b...
# 4  http://musicbrainz.org/recording/443819eb-6092...
#
#                                    mbid observations  tonic  verified
# 0  00f1c6d9-c8ee-45e3-a06f-0882ebcb4e2f               256.0     False
# 1  168f7c75-84fb-4316-99d7-acabadd3b2e6               115.2     False
# 2  24f549dd-3fa4-4e9b-a356-778fbbfd5cad               232.5     False
# 3  407bb0b4-f19b-42ab-8c0a-9f1263126951               233.5     False
# 4  443819eb-6092-420c-bd86-d946a0ad6555               219.6     False

# %% [markdown]
# ## Time Delayed Melody Surfaces
#
# Loading is part of the experiment

# %%
tdms_runs = mre.mlflow_common.get_runs_with_same_name(
    mre.data.TimeDelayedMelodySurface.EXPERIMENT_NAME,
    mre.data.TimeDelayedMelodySurface.RUN_NAME
)
time_delay_indices = tdms_runs['tags.time_delay_index'].values.astype(float)

# %% [markdown]
# # Experimental Setup

# %%
ARCHITECTURES = [
    mre.experimentation.Architecture(  # from yesiler et al
        name="MultiLayerPerceptron",
        estimator=MLPClassifier(
            momentum=0.5,
            max_iter=10000,
            learning_rate="adaptive",
            learning_rate_init=0.001),
        param_grid={
            "hidden_layer_sizes": [50, 100],
            "alpha": [0.01, 0.001]
        }
    ),
    mre.experimentation.Architecture(  # from demirel et al
        name="SVM",
        estimator=SVC(kernel="rbf", probability=True),
        param_grid={
            "C": [100],  # .001, .01, .1, 1, 10 give worse results, omitted
            "gamma": [10]  # .001, .01, .01 give worse results, omitted
        }
    ),
    mre.experimentation.Architecture(  # from karakurt et al (morty)
        name="KNN",
        estimator=KNeighborsClassifier(),
        param_grid={
            "n_neighbors": [1, 3],
            "weights": ["distance"],  # "uniform" give worse results, omitted 
            "metric": [bhat, "manhattan"]  # "euclidean" gives worse results, omitted
        }
    ),
    mre.experimentation.Architecture(
        name="LogisticRegression",
        estimator=LogisticRegression(max_iter=100, solver="saga"),
        param_grid={
            "penalty": ["l2", 'l1'],
            "C": [0.1, 1, 10]
        }
    ),
# #     mre.experimentation.Architecture(  # overfits heavily, omitted
# #         name="RandomForest",
# #         estimator=RandomForestClassifier(),
# #         param_grid={
# #             "n_estimators": [5, 10, 25, 50],
# #             "criterion": ["gini", "entropy"],
# #             "max_depth": [5, 10, 25, 50]
# #         }
# #     ),
# #     mre.experimentation.Architecture(  # bad overall; commented
# #         name="DecisionTree",
# #         estimator=DecisionTreeClassifier(),
# #         param_grid={
# #             "criterion": ["gini", "entropy"],
# #             "max_depth": [5, 10, 25, 50]
# #         }
# #     ),
]

# %%
# tdms_param_grid = {
#     "compression_exponent": [0.1, 0.25, 0.5, 0.75, 1],
#     "kernel_width": [0, 12.5, 25, 50],
# }

tdms_param_grid = {
    "compression_exponent": [1, 0.5],
    "kernel_width": [12.5, 0],
    "time_delay_index": time_delay_indices
}

# %% [markdown]
# ## Run 10-times shuffle split for each parameter combination

# %%
def run_experiment_for_tdms_param(time_delay_index, compression_exponent, kernel_width, num_trials):
    print("==================================================================================================")
    print(f"Running shuffled stratified cross validation experiment with {num_trials} repetitions.")
    print(f"Compression_exponent {compression_exponent}, kernel_width {kernel_width}, time_delay_index {time_delay_index}")
    tdms_files = mre.data.TimeDelayedMelodySurface.from_mlflow(
        time_delay_index=time_delay_index,
        compression_exponent=None,  # used below
        kernel_width=None  # used below
    )

    dataset = prepare_dataset(
        annotations,
        tdms_files,
        compression_exponent=compression_exponent,
        kernel_width=kernel_width
    )
    print(dataset)
    
    stratified_shuffle_cv_experiment = mre.experimentation.StratifiedShuffleCV(
        num_splits=10, num_trials=num_trials
    )

    # only run on SVM
    raw_scores = stratified_shuffle_cv_experiment.run(dataset, [ARCHITECTURES[1]])
    # display(stratified_shuffle_cv_experiment.results.head())
    
    _ = stratified_shuffle_cv_experiment.boxplot_best_models()
    plt.show()
    
    print("")
    
    return {
        "compression_exponent": compression_exponent,
        "kernel_width": kernel_width,
        "experiment": stratified_shuffle_cv_experiment,
        "raw_scores": raw_scores,
    }

# %% [markdown]
# # Evaluate different shallow architectures under different TDM params

# %%
experiments = []
all_results = pd.DataFrame()
for tau in tdms_param_grid["time_delay_index"]:
    for co in tdms_param_grid["compression_exponent"]:
        for kw in tdms_param_grid["kernel_width"]:
            tmp_exp = run_experiment_for_tdms_param(
                time_delay_index=tau,
                compression_exponent=co,
                kernel_width=kw,
                num_trials=10
            )
            tmp_exp["experiment"].results["compression_exponent"] = tmp_exp['compression_exponent']
            tmp_exp["experiment"].results["kernel_width"] = tmp_exp['kernel_width']
            tmp_exp["experiment"].results["time_delay_index"] = tau

            all_results = pd.concat([all_results, tmp_exp["experiment"].results])

            experiments.append(tmp_exp)
# Out:
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 12.5, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.77, Train acc: 0.94∓0.00, Refit time: 7.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.76, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.79, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.74, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.76, Train acc: 0.94∓0.00, Refit time: 7.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.79, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.75, Train acc: 0.94∓0.00, Refit time: 7.3 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.70, Train acc: 0.95∓0.00, Refit time: 7.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.73, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.81, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 0, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.78, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.77, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.80, Train acc: 0.96∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.72, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.76, Train acc: 0.97∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.81, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.72, Train acc: 0.97∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.66, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.75, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.78, Train acc: 0.97∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 12.5, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 19.4 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.81, Train acc: 1.00∓0.00, Refit time: 20.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.76, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.84, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.81, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.76, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.67, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.79, Train acc: 1.00∓0.00, Refit time: 18.7 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 0, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.69, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.78, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.84, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.77, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.64, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.73, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 12.5, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.16, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.15, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.15, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.18, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 0, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.17, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.14, Train acc: 1.00∓0.00, Refit time: 20.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 20.3 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.14, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 12.5, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.74, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.73, Train acc: 0.94∓0.00, Refit time: 7.4 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.72, Train acc: 0.94∓0.01, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.74, Train acc: 0.94∓0.00, Refit time: 7.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.70, Train acc: 0.94∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.75, Train acc: 0.94∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.72, Train acc: 0.94∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.68, Train acc: 0.95∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.72, Train acc: 0.95∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.74, Train acc: 0.94∓0.00, Refit time: 7.5 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 0, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.74, Train acc: 0.97∓0.00, Refit time: 7.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.73, Train acc: 0.97∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.73, Train acc: 0.96∓0.00, Refit time: 7.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.72, Train acc: 0.97∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.73, Train acc: 0.97∓0.00, Refit time: 7.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.74, Train acc: 0.96∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.71, Train acc: 0.97∓0.00, Refit time: 8.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.68, Train acc: 0.97∓0.00, Refit time: 7.3 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.70, Train acc: 0.97∓0.00, Refit time: 7.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.71, Train acc: 0.97∓0.00, Refit time: 7.6 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 12.5, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.79, Train acc: 1.00∓0.00, Refit time: 20.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 20.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 20.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.81, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.77, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.77, Train acc: 1.00∓0.00, Refit time: 19.8 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 0, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 19.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.65, Train acc: 1.00∓0.00, Refit time: 20.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.77, Train acc: 1.00∓0.00, Refit time: 20.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.68, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 20.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.83, Train acc: 1.00∓0.00, Refit time: 19.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 20.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 25.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.68, Train acc: 1.00∓0.00, Refit time: 30.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.9 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 12.5, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.14, Train acc: 1.00∓0.00, Refit time: 19.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.16, Train acc: 1.00∓0.00, Refit time: 21.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.15, Train acc: 1.00∓0.00, Refit time: 20.4 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 20.3 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 20.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 20.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.14, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 0, time_delay_index 0.5
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.16, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 21.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 21.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 20.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 21.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.14, Train acc: 1.00∓0.00, Refit time: 19.4 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 12.5, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.77, Train acc: 0.93∓0.00, Refit time: 6.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.66, Train acc: 0.93∓0.00, Refit time: 6.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.74, Train acc: 0.93∓0.00, Refit time: 6.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.74, Train acc: 0.93∓0.00, Refit time: 6.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.69, Train acc: 0.93∓0.00, Refit time: 6.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.80, Train acc: 0.92∓0.00, Refit time: 6.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.71, Train acc: 0.93∓0.00, Refit time: 6.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.66, Train acc: 0.93∓0.00, Refit time: 6.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.73, Train acc: 0.93∓0.00, Refit time: 6.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.72, Train acc: 0.93∓0.00, Refit time: 6.6 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 1, kernel_width 0, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.75, Train acc: 0.96∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.65, Train acc: 0.96∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.74, Train acc: 0.96∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.73, Train acc: 0.96∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.67, Train acc: 0.96∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.77, Train acc: 0.95∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.71, Train acc: 0.96∓0.00, Refit time: 7.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.70, Train acc: 0.96∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.73, Train acc: 0.96∓0.00, Refit time: 6.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.67, Train acc: 0.96∓0.00, Refit time: 7.0 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 12.5, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.73, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.79, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 19.0 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.84, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.77, Train acc: 1.00∓0.00, Refit time: 18.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 18.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 18.7 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 0, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.67, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.80, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.85, Train acc: 1.00∓0.00, Refit time: 19.3 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 19.2 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 19.3 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 12.5, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.16, Train acc: 1.00∓0.00, Refit time: 19.8 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.15, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.09, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 20.1 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.25, kernel_width 0, time_delay_index 0.25
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    SVM, Test acc: 0.10, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 1
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 2
#    SVM, Test acc: 0.13, Train acc: 1.00∓0.00, Refit time: 20.9 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 3
#    SVM, Test acc: 0.07, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 4
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 5
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 6
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 7
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.7 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 8
#    SVM, Test acc: 0.11, Train acc: 1.00∓0.00, Refit time: 19.5 sec, Best Params: {'C': 100, 'gamma': 10}
# Trial 9
#    SVM, Test acc: 0.12, Train acc: 1.00∓0.00, Refit time: 19.6 sec, Best Params: {'C': 100, 'gamma': 10}

# %%
(
    all_results
    .groupby(["architecture", "compression_exponent", "kernel_width", "time_delay_index"])
    ["test_score"]
    .agg(["mean", "std"])
    .sort_values("mean")
)
# Out:
#                                                                   mean  \
# architecture compression_exponent kernel_width time_delay_index
# SVM          0.25                 0.0          0.25              0.110
#                                                0.50              0.116
#                                   12.5         0.25              0.121
#                                   0.0          1.00              0.122
#                                   12.5         0.50              0.125
#                                                1.00              0.131
#              1.00                 0.0          0.25              0.712
#                                                0.50              0.719
#              0.50                 0.0          0.50              0.721
#              1.00                 12.5         0.25              0.722
#                                                0.50              0.724
#              0.50                 0.0          1.00              0.732
#                                                0.25              0.738
#                                   12.5         0.50              0.748
#                                                0.25              0.753
#              1.00                 0.0          1.00              0.755
#                                   12.5         1.00              0.760
#              0.50                 12.5         1.00              0.765
#
#                                                                       std
# architecture compression_exponent kernel_width time_delay_index
# SVM          0.25                 0.0          0.25              0.016997
#                                                0.50              0.023664
#                                   12.5         0.25              0.022828
#                                   0.0          1.00              0.023476
#                                   12.5         0.50              0.022236
#                                                1.00              0.027264
#              1.00                 0.0          0.25              0.039101
#                                                0.50              0.019120
#              0.50                 0.0          0.50              0.052589
#              1.00                 12.5         0.25              0.044672
#                                                0.50              0.021187
#              0.50                 0.0          1.00              0.055136
#                                                0.25              0.052873
#                                   12.5         0.50              0.037653
#                                                0.25              0.038312
#              1.00                 0.0          1.00              0.044783
#                                   12.5         1.00              0.032318
#              0.50                 12.5         1.00              0.049721

# %% [markdown]
# ### Box plot across experiments

# %%
g = sns.catplot(
    col="kernel_width",
    y="test_score",
    hue="time_delay_index",
    x="compression_exponent",
    data=all_results[all_results.architecture=="SVM"],
    kind="box",
    aspect=.7,
    palette="Set3",
    
)

# %%
for exp in experiments:
    print(
        f"compression_exponent: {exp['experiment'].results.compression_exponent.iloc[0]} "
        f"kernel_width: {exp['experiment'].results.kernel_width.iloc[0]} "
        f"time_delay_index: {exp['experiment'].results.time_delay_index.iloc[0]} "
    )
    exp['experiment'].plot_confusion_matrix(architecture="SVM")
    plt.show()
# Out:
# compression_exponent: 1 kernel_width: 12.5 time_delay_index: 1.0
# INFO:numexpr.utils:NumExpr defaulting to 6 threads.
# compression_exponent: 1 kernel_width: 0 time_delay_index: 1.0
# compression_exponent: 0.5 kernel_width: 12.5 time_delay_index: 1.0
# compression_exponent: 0.5 kernel_width: 0 time_delay_index: 1.0
# compression_exponent: 0.25 kernel_width: 12.5 time_delay_index: 1.0
# compression_exponent: 0.25 kernel_width: 0 time_delay_index: 1.0
# compression_exponent: 1 kernel_width: 12.5 time_delay_index: 0.5
# compression_exponent: 1 kernel_width: 0 time_delay_index: 0.5
# compression_exponent: 0.5 kernel_width: 12.5 time_delay_index: 0.5
# compression_exponent: 0.5 kernel_width: 0 time_delay_index: 0.5
# compression_exponent: 0.25 kernel_width: 12.5 time_delay_index: 0.5
# compression_exponent: 0.25 kernel_width: 0 time_delay_index: 0.5
# compression_exponent: 1 kernel_width: 12.5 time_delay_index: 0.25
# compression_exponent: 1 kernel_width: 0 time_delay_index: 0.25
# compression_exponent: 0.5 kernel_width: 12.5 time_delay_index: 0.25
# compression_exponent: 0.5 kernel_width: 0 time_delay_index: 0.25
# compression_exponent: 0.25 kernel_width: 12.5 time_delay_index: 0.25
# compression_exponent: 0.25 kernel_width: 0 time_delay_index: 0.25

# %% [markdown]
# ## Evaluate on the optimal parameters

# %%
OPTIMAL_TDMS_PARAMS = { 
    "time_delay_index":1.00,
    "compression_exponent":0.50,
    "kernel_width":12.5,
}
optimal_tdms_exp = run_experiment_for_tdms_param(
    **OPTIMAL_TDMS_PARAMS,
    num_trials=10
)
# Out:
# ==================================================================================================
# Running shuffled stratified cross validation experiment with 10 repetitions.
# Compression_exponent 0.5, kernel_width 12.5, time_delay_index 1.0
# Dataset with 1000 samples and 2304 feature dimensions.
# Trial 0
#    MultiLayerPerceptron, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 129.0 sec, Best Params: {'alpha': 0.01, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 26.7 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.69, Train acc: 1.00∓0.00, Refit time: 0.2 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.74, Train acc: 0.92∓0.01, Refit time: 49.4 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 1
#    MultiLayerPerceptron, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 24.7 sec, Best Params: {'alpha': 0.001, 'hidden_layer_sizes': 50}
#    SVM                 , Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 19.1 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.67, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.73, Train acc: 0.92∓0.01, Refit time: 36.2 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 2
#    MultiLayerPerceptron, Test acc: 0.72, Train acc: 1.00∓0.00, Refit time: 71.9 sec, Best Params: {'alpha': 0.001, 'hidden_layer_sizes': 50}
#    SVM                 , Test acc: 0.81, Train acc: 1.00∓0.00, Refit time: 23.2 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.73, Train acc: 1.00∓0.00, Refit time: 0.2 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.78, Train acc: 0.92∓0.01, Refit time: 41.8 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 3
#    MultiLayerPerceptron, Test acc: 0.68, Train acc: 1.00∓0.00, Refit time: 77.6 sec, Best Params: {'alpha': 0.001, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 34.1 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.71, Train acc: 1.00∓0.00, Refit time: 0.2 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.74, Train acc: 0.93∓0.00, Refit time: 35.7 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 4
#    MultiLayerPerceptron, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 50.0 sec, Best Params: {'alpha': 0.01, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.76, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.75, Train acc: 0.93∓0.01, Refit time: 34.9 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 5
#    MultiLayerPerceptron, Test acc: 0.84, Train acc: 1.00∓0.00, Refit time: 48.9 sec, Best Params: {'alpha': 0.01, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.84, Train acc: 1.00∓0.00, Refit time: 19.3 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.75, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.85, Train acc: 0.92∓0.01, Refit time: 38.3 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 6
#    MultiLayerPerceptron, Test acc: 0.78, Train acc: 1.00∓0.00, Refit time: 38.4 sec, Best Params: {'alpha': 0.01, 'hidden_layer_sizes': 50}
#    SVM                 , Test acc: 0.81, Train acc: 1.00∓0.00, Refit time: 18.9 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.79, Train acc: 0.93∓0.00, Refit time: 36.0 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 7
#    MultiLayerPerceptron, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 30.2 sec, Best Params: {'alpha': 0.001, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.76, Train acc: 1.00∓0.00, Refit time: 18.7 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.71, Train acc: 0.92∓0.00, Refit time: 35.9 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 8
#    MultiLayerPerceptron, Test acc: 0.74, Train acc: 1.00∓0.00, Refit time: 22.7 sec, Best Params: {'alpha': 0.001, 'hidden_layer_sizes': 50}
#    SVM                 , Test acc: 0.67, Train acc: 1.00∓0.00, Refit time: 18.8 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.66, Train acc: 1.00∓0.00, Refit time: 0.1 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.74, Train acc: 0.93∓0.00, Refit time: 36.7 sec, Best Params: {'C': 10, 'penalty': 'l2'}
# Trial 9
#    MultiLayerPerceptron, Test acc: 0.70, Train acc: 1.00∓0.00, Refit time: 180.7 sec, Best Params: {'alpha': 0.01, 'hidden_layer_sizes': 100}
#    SVM                 , Test acc: 0.79, Train acc: 1.00∓0.00, Refit time: 25.6 sec, Best Params: {'C': 100, 'gamma': 10}
#    KNN                 , Test acc: 0.67, Train acc: 1.00∓0.00, Refit time: 0.2 sec, Best Params: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
#    LogisticRegression  , Test acc: 0.72, Train acc: 0.92∓0.00, Refit time: 70.2 sec, Best Params: {'C': 10, 'penalty': 'l2'}

# %%
(
    optimal_tdms_exp['experiment'].results
    .groupby(["architecture"])
    ["test_score"]
    .agg(["mean", "std"])
    .sort_values("mean")
)
# Out:
#                        mean       std
# architecture
# KNN                   0.702  0.030840
# MultiLayerPerceptron  0.734  0.047188
# LogisticRegression    0.755  0.041433
# SVM                   0.765  0.049721

# %% [markdown]
# ### Box plot across experiments

# %%
g = sns.boxplot(
    y="test_score",
    x="architecture",
    data=optimal_tdms_exp['experiment'].results,
    palette="Set3",
)
plt.grid()

# %%
optimal_tdms_exp['experiment'].plot_confusion_matrix(architecture="SVM")
plt.show()
